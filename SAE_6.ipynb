# %%
from keras.layers import Input, Dense
from keras.models import Model, load_model
from keras import backend as K
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
from keras.callbacks import *
from keras import regularizers
from keras import optimizers
# sklearn
from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, auc, precision_score, recall_score
from sklearn.preprocessing import MinMaxScaler

# other
import time

# %%
# load training dataset
data_path = "./data/"
df_train_orig = pd.read_csv(data_path + "dataset03.csv", parse_dates = ['DATETIME'], dayfirst=True)

# %%
# get dates and columns with sensor readings
dates_train = df_train_orig['DATETIME']
sensor_cols = [col for col in df_train_orig.columns if col not in ['DATETIME','ATT_FLAG']]

# scale sensor data
scaler = MinMaxScaler()
X = pd.DataFrame(index = df_train_orig.index, columns = sensor_cols, data = scaler.fit_transform(df_train_orig[sensor_cols]))

# split into training and validation
X1, X2, _, _  = train_test_split(X, X, test_size=0.33, random_state=42)
#X:8761,X1:5869,X2:2892

# %%
# Load dataset with attacks
df_test_01 = pd.read_csv(data_path + "dataset04.csv", parse_dates = ['DATETIME'], dayfirst=True)
df_test_02 = pd.read_csv(data_path + "test_dataset.csv", parse_dates = ['DATETIME'], dayfirst=True)

# scale datasets
X3 = pd.DataFrame(index = df_test_01.index, columns = sensor_cols, 
                  data = scaler.transform(df_test_01[sensor_cols]))
X4 = pd.DataFrame(index = df_test_02.index, columns = sensor_cols, 
                  data = scaler.transform(df_test_02[sensor_cols]))

# get targets
Y3 = df_test_01['ATT_FLAG']
Y4 = df_test_02['ATT_FLAG']
#Y3:valid_label,4177;Y4:test_label,2089

# %%
origin_dim = X1.shape[1]
epochs_layer = 30
epochs_whole = 100
batch_size = 32
h_dim1 = 32
h_dim2 = 16
h_dim3 = 8

# %%
def f2_score(label, predict):
    p = precision_score(label, predict)
    r = recall_score(label, predict)
    f2_score = 5*p*r / (4*p + r)
    return f2_score

# %%
# assess detection
def compute_scores(Y,Yhat):
    return [accuracy_score(Y,Yhat),f1_score(Y,Yhat),precision_score(Y,Yhat),recall_score(Y,Yhat),f2_score(Y,Yhat)]

# %%
def cm_plot(original_label, predict_label, pic=None):
    cm = confusion_matrix(original_label, predict_label)   # 由原标签和预测标签生成混淆矩阵
    plt.figure(figsize = (10,10))
    plt.matshow(cm, cmap=plt.cm.Blues)     # 画混淆矩阵，配色风格使用cm.Blues
    plt.colorbar()    # 颜色标签
    for x in range(len(cm)):
        for y in range(len(cm)):
            plt.annotate(cm[x, y], xy=(x, y), horizontalalignment='center', verticalalignment='center')
            # annotate主要在图形中添加注释
            # 第一个参数添加注释
            # 第二个参数是注释的内容
            # xy设置箭头尖的坐标
            # horizontalalignment水平对齐
            # verticalalignment垂直对齐
            # 其余常用参数如下:
            # xytext设置注释内容显示的起始位置
            # arrowprops 用来设置箭头
            # facecolor 设置箭头的颜色
            # headlength 箭头的头的长度
            # headwidth 箭头的宽度
            # width 箭身的宽度
    plt.ylabel('True label')  # 坐标轴标签
    plt.xlabel('Predicted label')  # 坐标轴标签
    plt.title('confusion matrix')
    if pic is not None:
        plt.savefig(str(pic) + '.jpg')
    plt.show()

# %%
def pred_error(preds,x):
        #preds = preds.reshape(preds.shape[0],preds.shape[1])
        #x=x.reshape(x.shape[0],x.shape[1])
        errors = (x-preds)**2
        return preds, errors

# %%
def detect(preds,x, theta, window = 1, average=False, sys_theta = 0):
        preds, temp = pred_error(preds,x)
        #x=x.reshape(x.shape[0],x.shape[1])
        temp = (x-preds)**2
        #temp = pd.DataFrame(temp)
        if average:
            errors = temp.mean(axis=1).rolling(window=window).mean()
            detection = errors > theta
        else:
            errors = temp.rolling(window=window).mean()
            detection = errors.apply(lambda x: x>np.max(theta.name, sys_theta))

        return detection, errors

# %%
##### 设置网络参数 #####
p = 0.05  # 使大部分神经元的激活值（所有神经元的激活值的平均值）接近这个p值
beta = 3  # 控制KL散度所占的比重
lambda_val = 0.001  # weight decay
# 自定义正则项函数, 计算KL散度
def sparse_reg(activity_matrix):
        activity_matrix = K.softmax(activity_matrix, axis=0)  # 把激活值先用softmax归一化
        p_hat = K.mean(activity_matrix, axis=0)  # 将第j个神经元在batch_size个输入下所有的输出激活值取平均
        print('p_hat=', p_hat)
        KLD = p*(K.log(p/p_hat))+(1-p)*(K.log((1-p)/(1-p_hat)))  # 计算KL散度
        print('KLD=', KLD)
        return beta*K.sum(KLD)  # 所有神经元的KL散度相加并乘以beta

# %%
adam = tf.optimizers.Adam(lr = 0.001)
# Out:
# D:\anaconda\Anaconda\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# train models with early stopping and reduction of learning rate on plateau
earlyStopping= EarlyStopping(monitor='val_loss', patience=3, verbose=0,  min_delta=1e-4, mode='auto')
lr_reduced = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=1, verbose=0, epsilon=1e-4, mode='min')
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
##### 构建单个autoencoder #####
class AutoEncoderLayer():
    def __init__(self, input_dim, output_dim):
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.build()

    def build(self):
        self.input = Input(shape=(self.input_dim,))
        self.encode_layer = Dense(self.output_dim, activation='tanh')
        self.encoded = self.encode_layer(self.input)
        self.encoder = Model(self.input, self.encoded)

        self.decode_layer = Dense(self.input_dim, activation='tanh')
        self.decoded = self.decode_layer(self.encoded)

        self.autoencoder = Model(self.input, self.decoded)

# %%
# 构建堆叠DAE
class StackedAutoEncoder():
    def __init__(self, layer_list):
        self.layer_list = layer_list
        self.build()

    def build(self):
        out = self.layer_list[0].encoded
        for i in range(1, num_layers - 1):
            out = self.layer_list[i].encode_layer(out)
        self.model = Model(self.layer_list[0].input, out)

# %%
def train_layers(encoder_list=None, layer=None, epochs=None, batch_size=None):
    
    #预训练：逐层训练，当训练第layer个ae时，使用前（layer-1）个ae训练好的encoder的参数
    #:param encoder_list:
    #:param layer:
    #:param epochs:
    #:param batch_size:
    #:return:
    
    # 对前(layer-1)层用已经训练好的参数进行前向计算，ps:第0层没有前置层
    out = X1
    origin = X1
    if layer != 0:
        for i in range(layer):
            # print("encoder weight", str(i), ":", encoder_list[i].encoder.get_weights()[0])
            out = encoder_list[i].encoder.predict(out)

    encoder_list[layer].autoencoder.summary()
    encoder_list[layer].autoencoder.compile(optimizer=adam, loss='mse')

    # 训练第layer个ae
    layer = encoder_list[layer].autoencoder.fit(
        out,
        origin if layer == 0 else out,
        epochs=epochs,
        batch_size=batch_size,
        callbacks = [earlyStopping, lr_reduced],
        shuffle=True,
        verbose=2
    )
    plt.figure()
 


    loss = layer.history['loss']
    #val_loss = layer.history['val_loss']
 
    epochs = range(len(loss))
 

 
    plt.figure()
 
    plt.plot(epochs, loss, 'b', label='Training loss',linestyle='-.')
    #plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('6 layers SAE Training layers loss')
    plt.legend()
 
    plt.show()

# %%
def train_whole(sae=None, epochs=None, batch_size=None):
    
    #用预训练好的参数初始化stacked ae的参数，然后进行全局训练优化
    #:param model:
    #:param epochs:
    #:param batch_size:
    #:return:
    
    # print("stacked sae weights:")
    # print(sae.model.get_weights())
    sae.model.summary()
    sae.model.compile(optimizer=adam, loss='mse')
    whole = sae.model.fit(
        X1,
        X1,
        epochs=epochs,
        batch_size=batch_size,
        callbacks = [earlyStopping, lr_reduced],
        shuffle=True,
        validation_data=(X2,X2),
        verbose=2
    )
    plt.figure()
 


    loss = whole.history['loss']
    val_loss = whole.history['val_loss']
 
    epochs = range(len(loss))
 

 
    plt.figure()
 
    plt.plot(epochs, loss, 'y', label='Training loss',linestyle=':')
    plt.plot(epochs, val_loss, 'b', label='Validation loss',linestyle='-.')
    plt.title('6 layers SAE Training and validation loss')
    plt.legend()
 
    plt.show()

# %%
# 7层的stacked ae，实际上要使用6个ae，实例化6个ae
num_layers = 7
encoder_1 = AutoEncoderLayer(origin_dim, h_dim1)
encoder_2 = AutoEncoderLayer(h_dim1, h_dim2)
encoder_3 = AutoEncoderLayer(h_dim2, h_dim3)

decoder_4 = AutoEncoderLayer(h_dim3, h_dim2)
decoder_5 = AutoEncoderLayer(h_dim2, h_dim1)
decoder_6 = AutoEncoderLayer(h_dim1, origin_dim)
autoencoder_list = [encoder_1,encoder_2,encoder_3,decoder_4,decoder_5,decoder_6]

# 按照顺序对每一层进行预训练
print("Pre training:")
for level in range(num_layers - 1):
    print("level:", level)
    train_layers(encoder_list=autoencoder_list, layer=level, epochs=epochs_layer, batch_size=batch_size)


# 用训练好的4个ae构建stacked dae
stacked_ae = StackedAutoEncoder(autoencoder_list)
print("Whole training:")
# 进行全局训练优化
train_whole(sae=stacked_ae, epochs=epochs_whole, batch_size=batch_size)
# Out:
# Pre training:
# level: 0
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 43)]              0
#
#  dense (Dense)               (None, 32)                1408
#
#  dense_1 (Dense)             (None, 43)                1419
#
# =================================================================
# Total params: 2,827
# Trainable params: 2,827
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.1136 - lr: 0.0010 - 401ms/epoch - 2ms/step
# Epoch 2/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0293 - lr: 0.0010 - 99ms/epoch - 537us/step
# Epoch 3/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0149 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 4/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0091 - lr: 0.0010 - 99ms/epoch - 537us/step
# Epoch 5/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0067 - lr: 0.0010 - 102ms/epoch - 553us/step
# Epoch 6/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0052 - lr: 0.0010 - 100ms/epoch - 542us/step
# Epoch 7/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0042 - lr: 0.0010 - 99ms/epoch - 537us/step
# Epoch 8/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0033 - lr: 0.0010 - 100ms/epoch - 542us/step
# Epoch 9/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0027 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 10/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0022 - lr: 0.0010 - 103ms/epoch - 558us/step
# Epoch 11/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0019 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 12/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0016 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 13/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0015 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 14/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0013 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 15/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0012 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 16/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0012 - lr: 0.0010 - 101ms/epoch - 547us/step
# Epoch 17/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0011 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 18/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0010 - lr: 0.0010 - 103ms/epoch - 558us/step
# Epoch 19/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 9.9884e-04 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 20/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 9.5496e-04 - lr: 0.0010 - 99ms/epoch - 537us/step
# Epoch 21/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 9.1706e-04 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 22/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 8.8952e-04 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 23/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 8.6036e-04 - lr: 0.0010 - 100ms/epoch - 542us/step
# Epoch 24/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 8.3587e-04 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 25/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 8.1103e-04 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 26/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.8974e-04 - lr: 0.0010 - 96ms/epoch - 520us/step
# Epoch 27/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.7035e-04 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 28/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.5274e-04 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 29/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.4081e-04 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 30/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.2231e-04 - lr: 0.0010 - 96ms/epoch - 520us/step
# level: 1
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32)]              0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 32)                544
#
# =================================================================
# Total params: 1,072
# Trainable params: 1,072
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0292 - lr: 0.0010 - 424ms/epoch - 2ms/step
# Epoch 2/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0056 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 3/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0035 - lr: 0.0010 - 93ms/epoch - 504us/step
# Epoch 4/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0025 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 5/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0020 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 6/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0016 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 7/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0014 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 8/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0011 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 9/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 9.9488e-04 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 10/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 8.8646e-04 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 11/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 8.0147e-04 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 12/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.3119e-04 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 13/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.6811e-04 - lr: 0.0010 - 93ms/epoch - 504us/step
# Epoch 14/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.1268e-04 - lr: 0.0010 - 96ms/epoch - 520us/step
# Epoch 15/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.6087e-04 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 16/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.1852e-04 - lr: 0.0010 - 107ms/epoch - 580us/step
# Epoch 17/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 4.8091e-04 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 18/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 4.4877e-04 - lr: 0.0010 - 96ms/epoch - 520us/step
# Epoch 19/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 4.2262e-04 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 20/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 4.0002e-04 - lr: 0.0010 - 96ms/epoch - 520us/step
# Epoch 21/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.8016e-04 - lr: 0.0010 - 96ms/epoch - 520us/step
# Epoch 22/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.6383e-04 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 23/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.4732e-04 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 24/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.3364e-04 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 25/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.2059e-04 - lr: 0.0010 - 100ms/epoch - 542us/step
# Epoch 26/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.1162e-04 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 27/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.0078e-04 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 28/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 2.9223e-04 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 29/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 2.8382e-04 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 30/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 2.7699e-04 - lr: 0.0010 - 98ms/epoch - 531us/step
# level: 2
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 16)]              0
#
#  dense_4 (Dense)             (None, 8)                 136
#
#  dense_5 (Dense)             (None, 16)                144
#
# =================================================================
# Total params: 280
# Trainable params: 280
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0372 - lr: 0.0010 - 349ms/epoch - 2ms/step
# Epoch 2/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0130 - lr: 0.0010 - 104ms/epoch - 564us/step
# Epoch 3/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0108 - lr: 0.0010 - 110ms/epoch - 596us/step
# Epoch 4/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0100 - lr: 0.0010 - 102ms/epoch - 553us/step
# Epoch 5/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0096 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 6/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0094 - lr: 0.0010 - 92ms/epoch - 499us/step
# Epoch 7/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0092 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 8/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0091 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 9/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0090 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 10/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0089 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 11/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0088 - lr: 0.0010 - 89ms/epoch - 482us/step
# Epoch 12/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0088 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 13/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0087 - lr: 0.0010 - 92ms/epoch - 499us/step
# Epoch 14/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0087 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 15/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0086 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 16/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0086 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 17/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0086 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 18/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0085 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 19/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0085 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 20/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0085 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 21/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0084 - lr: 0.0010 - 89ms/epoch - 482us/step
# Epoch 22/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0084 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 23/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0084 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 24/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0084 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 25/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0084 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 26/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0083 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 27/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0083 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 28/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0083 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 29/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0083 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 30/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0083 - lr: 0.0010 - 91ms/epoch - 493us/step
# level: 3
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 8)]               0
#
#  dense_6 (Dense)             (None, 16)                144
#
#  dense_7 (Dense)             (None, 8)                 136
#
# =================================================================
# Total params: 280
# Trainable params: 280
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0095 - lr: 0.0010 - 354ms/epoch - 2ms/step
# Epoch 2/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 1.0627e-04 - lr: 0.0010 - 92ms/epoch - 499us/step
# Epoch 3/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 9.8564e-05 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 4/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 9.4247e-05 - lr: 0.0010 - 92ms/epoch - 499us/step
# Epoch 5/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 8.9724e-05 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 6/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 8.6502e-05 - lr: 0.0010 - 101ms/epoch - 547us/step
# Epoch 7/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 8.2969e-05 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 8/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.9753e-05 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 9/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.7074e-05 - lr: 0.0010 - 92ms/epoch - 499us/step
# Epoch 10/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.5016e-05 - lr: 0.0010 - 92ms/epoch - 499us/step
# Epoch 11/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.3048e-05 - lr: 0.0010 - 92ms/epoch - 499us/step
# Epoch 12/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.1372e-05 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 13/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.9066e-05 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 14/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.7777e-05 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 15/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.6224e-05 - lr: 0.0010 - 92ms/epoch - 499us/step
# Epoch 16/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.4577e-05 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 17/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.3555e-05 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 18/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.2070e-05 - lr: 0.0010 - 99ms/epoch - 537us/step
# Epoch 19/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.1102e-05 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 20/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.0373e-05 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 21/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.9326e-05 - lr: 0.0010 - 99ms/epoch - 537us/step
# Epoch 22/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.8195e-05 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 23/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.7539e-05 - lr: 0.0010 - 87ms/epoch - 472us/step
# Epoch 24/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.6774e-05 - lr: 0.0010 - 89ms/epoch - 481us/step
# Epoch 25/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.6404e-05 - lr: 0.0010 - 89ms/epoch - 482us/step
# Epoch 26/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.5032e-05 - lr: 0.0010 - 88ms/epoch - 477us/step
# Epoch 27/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.5254e-05 - lr: 0.0010 - 93ms/epoch - 504us/step
# Epoch 28/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.3910e-05 - lr: 0.0010 - 90ms/epoch - 488us/step
# Epoch 29/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.3587e-05 - lr: 0.0010 - 92ms/epoch - 499us/step
# Epoch 30/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.3479e-05 - lr: 0.0010 - 91ms/epoch - 493us/step
# level: 4
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 16)]              0
#
#  dense_8 (Dense)             (None, 32)                544
#
#  dense_9 (Dense)             (None, 16)                528
#
# =================================================================
# Total params: 1,072
# Trainable params: 1,072
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0032 - lr: 0.0010 - 375ms/epoch - 2ms/step
# Epoch 2/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 1.2310e-05 - lr: 0.0010 - 105ms/epoch - 571us/step
# Epoch 3/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 1.2065e-05 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 4/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 1.1945e-05 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 5/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 1.1643e-05 - lr: 0.0010 - 94ms/epoch - 513us/step
# Epoch 6/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 1.1468e-05 - lr: 0.0010 - 81ms/epoch - 443us/step
# Epoch 7/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 1.1259e-05 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 8/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 1.1022e-05 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 9/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 1.0729e-05 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 10/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 1.0612e-05 - lr: 0.0010 - 89ms/epoch - 482us/step
# Epoch 11/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 1.0436e-05 - lr: 0.0010 - 91ms/epoch - 493us/step
# Epoch 12/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# ...
# Epoch 28/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.2930e-06 - lr: 0.0010 - 96ms/epoch - 520us/step
# Epoch 29/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 7.2565e-06 - lr: 0.0010 - 92ms/epoch - 499us/step
# Epoch 30/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.9932e-06 - lr: 0.0010 - 95ms/epoch - 515us/step
# level: 5
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 32)]              0
#
#  dense_10 (Dense)            (None, 43)                1419
#
#  dense_11 (Dense)            (None, 32)                1408
#
# =================================================================
# Total params: 2,827
# Trainable params: 2,827
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 0.0014 - lr: 0.0010 - 361ms/epoch - 2ms/step
# Epoch 2/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.7452e-06 - lr: 0.0010 - 95ms/epoch - 519us/step
# Epoch 3/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.5744e-06 - lr: 0.0010 - 94ms/epoch - 513us/step
# Epoch 4/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.4203e-06 - lr: 0.0010 - 94ms/epoch - 511us/step
# Epoch 5/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.2473e-06 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 6/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 6.0827e-06 - lr: 0.0010 - 99ms/epoch - 537us/step
# Epoch 7/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.9106e-06 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 8/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.7498e-06 - lr: 0.0010 - 103ms/epoch - 558us/step
# Epoch 9/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.7057e-06 - lr: 0.0010 - 96ms/epoch - 520us/step
# Epoch 10/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.4702e-06 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 11/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.2917e-06 - lr: 0.0010 - 96ms/epoch - 521us/step
# Epoch 12/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.1503e-06 - lr: 0.0010 - 95ms/epoch - 515us/step
# Epoch 13/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 5.0258e-06 - lr: 0.0010 - 94ms/epoch - 511us/step
# Epoch 14/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 4.8982e-06 - lr: 0.0010 - 94ms/epoch - 513us/step
# Epoch 15/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 4.7318e-06 - lr: 0.0010 - 94ms/epoch - 510us/step
# Epoch 16/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 4.7065e-06 - lr: 0.0010 - 100ms/epoch - 542us/step
# Epoch 17/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 4.5630e-06 - lr: 0.0010 - 99ms/epoch - 537us/step
# Epoch 18/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 4.3847e-06 - lr: 0.0010 - 100ms/epoch - 542us/step
# Epoch 19/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 4.2994e-06 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 20/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 4.1763e-06 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 21/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 4.0465e-06 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 22/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.9702e-06 - lr: 0.0010 - 99ms/epoch - 537us/step
# Epoch 23/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.8134e-06 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 24/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.7493e-06 - lr: 0.0010 - 96ms/epoch - 520us/step
# Epoch 25/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.5761e-06 - lr: 0.0010 - 97ms/epoch - 526us/step
# Epoch 26/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.5231e-06 - lr: 0.0010 - 99ms/epoch - 537us/step
# Epoch 27/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.4971e-06 - lr: 0.0010 - 98ms/epoch - 531us/step
# Epoch 28/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.3978e-06 - lr: 0.0010 - 99ms/epoch - 537us/step
# Epoch 29/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.3505e-06 - lr: 0.0010 - 100ms/epoch - 542us/step
# Epoch 30/30
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 184/184 - 0s - loss: 3.1991e-06 - lr: 0.0010 - 98ms/epoch - 531us/step
# Whole training:
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 43)]              0
#
#  dense (Dense)               (None, 32)                1408
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 8)                 136
#
#  dense_6 (Dense)             (None, 16)                144
#
#  dense_8 (Dense)             (None, 32)                544
#
#  dense_10 (Dense)            (None, 43)                1419
#
# =================================================================
# Total params: 4,179
# Trainable params: 4,179
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 184/184 - 1s - loss: 0.0455 - val_loss: 0.0162 - lr: 0.0010 - 657ms/epoch - 4ms/step
# Epoch 2/100
# 184/184 - 0s - loss: 0.0126 - val_loss: 0.0095 - lr: 0.0010 - 169ms/epoch - 916us/step
# Epoch 3/100
# 184/184 - 0s - loss: 0.0091 - val_loss: 0.0083 - lr: 0.0010 - 175ms/epoch - 949us/step
# Epoch 4/100
# 184/184 - 0s - loss: 0.0080 - val_loss: 0.0074 - lr: 0.0010 - 166ms/epoch - 900us/step
# Epoch 5/100
# 184/184 - 0s - loss: 0.0074 - val_loss: 0.0070 - lr: 0.0010 - 160ms/epoch - 867us/step
# Epoch 6/100
# 184/184 - 0s - loss: 0.0070 - val_loss: 0.0068 - lr: 0.0010 - 162ms/epoch - 878us/step
# Epoch 7/100
# 184/184 - 0s - loss: 0.0067 - val_loss: 0.0065 - lr: 0.0010 - 164ms/epoch - 889us/step
# Epoch 8/100
# 184/184 - 0s - loss: 0.0065 - val_loss: 0.0063 - lr: 0.0010 - 169ms/epoch - 916us/step
# Epoch 9/100
# 184/184 - 0s - loss: 0.0063 - val_loss: 0.0061 - lr: 0.0010 - 163ms/epoch - 884us/step
# Epoch 10/100
# 184/184 - 0s - loss: 0.0061 - val_loss: 0.0058 - lr: 0.0010 - 161ms/epoch - 873us/step
# Epoch 11/100
# 184/184 - 0s - loss: 0.0059 - val_loss: 0.0057 - lr: 0.0010 - 160ms/epoch - 867us/step
# Epoch 12/100
# 184/184 - 0s - loss: 0.0057 - val_loss: 0.0055 - lr: 0.0010 - 162ms/epoch - 878us/step
# Epoch 13/100
# 184/184 - 0s - loss: 0.0055 - val_loss: 0.0052 - lr: 0.0010 - 165ms/epoch - 894us/step
# Epoch 14/100
# 184/184 - 0s - loss: 0.0053 - val_loss: 0.0050 - lr: 0.0010 - 161ms/epoch - 873us/step
# Epoch 15/100
# 184/184 - 0s - loss: 0.0051 - val_loss: 0.0048 - lr: 0.0010 - 163ms/epoch - 884us/step
# Epoch 16/100
# 184/184 - 0s - loss: 0.0048 - val_loss: 0.0046 - lr: 0.0010 - 161ms/epoch - 873us/step
# Epoch 17/100
# 184/184 - 0s - loss: 0.0046 - val_loss: 0.0043 - lr: 0.0010 - 160ms/epoch - 867us/step
# Epoch 18/100
# 184/184 - 0s - loss: 0.0043 - val_loss: 0.0040 - lr: 0.0010 - 167ms/epoch - 905us/step
# Epoch 19/100
# 184/184 - 0s - loss: 0.0041 - val_loss: 0.0038 - lr: 0.0010 - 170ms/epoch - 921us/step
# Epoch 20/100
# 184/184 - 0s - loss: 0.0039 - val_loss: 0.0037 - lr: 0.0010 - 165ms/epoch - 894us/step
# Epoch 21/100
# 184/184 - 0s - loss: 0.0037 - val_loss: 0.0036 - lr: 0.0010 - 162ms/epoch - 878us/step
# Epoch 22/100
# 184/184 - 0s - loss: 0.0035 - val_loss: 0.0034 - lr: 5.0000e-04 - 161ms/epoch - 873us/step
# Epoch 23/100
# 184/184 - 0s - loss: 0.0034 - val_loss: 0.0033 - lr: 5.0000e-04 - 164ms/epoch - 889us/step
# Epoch 24/100
# 184/184 - 0s - loss: 0.0034 - val_loss: 0.0033 - lr: 2.5000e-04 - 169ms/epoch - 916us/step
# Epoch 25/100
# 184/184 - 0s - loss: 0.0033 - val_loss: 0.0032 - lr: 2.5000e-04 - 172ms/epoch - 932us/step
# Epoch 26/100
# 184/184 - 0s - loss: 0.0033 - val_loss: 0.0032 - lr: 1.2500e-04 - 171ms/epoch - 927us/step
# Epoch 27/100
# 184/184 - 0s - loss: 0.0033 - val_loss: 0.0032 - lr: 6.2500e-05 - 168ms/epoch - 911us/step

# %%
##### 显示stacked dae重构后的效果 #####
X1_pre = stacked_ae.model.predict(X1)
X2_pre = stacked_ae.model.predict(X2)
X3_pre = stacked_ae.model.predict(X3)
X4_pre = stacked_ae.model.predict(X4)
print('X1: ',X1)
print('X1_pre: ',X1_pre)
print('X2: ',X2)
print('X2_pre: ',X2_pre)
print('X3: ',X3)
print('X3_pre: ',X3_pre)
print('X4: ',X2)
print('X4_pre: ',X4_pre)
# Out:
# X1:            L_T1      L_T2      L_T3      L_T4      L_T5      L_T6      L_T7  \
#  [0.30638164 0.44056082 0.65642935 ... 0.5177614  0.04511809 0.5663767 ]
#  [0.21602318 0.4623684  0.81023735 ... 0.13904679 0.07222706 0.5864337 ]
#  ...
#  [0.19050539 0.49316853 0.03937476 ... 0.2692096  0.04673807 0.48185572]
#  [0.21016273 0.4092179  0.22877407 ... 0.31489486 0.03677719 0.52324444]
#  [0.21622166 0.36419806 0.37757373 ... 0.337064   0.01141366 0.520681  ]]

# %%
# perform detection

# get validation reconstruction errors
_, validation_errors = pred_error(X2_pre,X2)

# plot distribution of average validation reconstruction errors 
f, ax = plt.subplots(1, figsize = (8,4))
sns.boxplot(validation_errors.mean(axis=1), ax=ax)
ax.set_xlim([0,0.005])
ax.set_title('Boxplot of average validation reconstruction errors')

# set treshold as quantile of average reconstruction error
theta1 = validation_errors.mean(axis = 1).quantile(0.993)
theta2 = validation_errors.mean(axis = 1).quantile(0.989)

Yhat3, _ = detect(X3_pre,X3, theta = theta1 , window = 3, average=True)
Yhat4, _ = detect(X4_pre,X4, theta = theta2, window = 3, average=True)

# %%
results = pd.DataFrame(index = ['test dataset 01','test dataset 02'], 
                       columns = ['accuracy','f1_score','precision','recall','f2_score'])
results.loc['test dataset 01'] = compute_scores(Y3,Yhat3)
results.loc['test dataset 02'] = compute_scores(Y4,Yhat4)

print('Results:\n')
print(results)
# Out:
# Results:
#
#                  accuracy  f1_score precision    recall  f2_score
# test dataset 01  0.928418  0.592087  0.900415  0.441057  0.491172
# test dataset 02  0.859742  0.479574  0.865385  0.331695  0.378363

# %%
# plot figures
font2 = {'family' : 'SimHei',#Times New Roman
        'weight' : 'normal',
        'size'   : 10,
            }
font1 = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 6,
            }
shade_of_gray = '0.75'
f_SAE6, axes = plt.subplots(2,figsize = (10,6))
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
axes[0].plot(Yhat3, color = 'r', label = '预测标签')#shade_of_gray
axes[0].fill_between(Yhat3.index, Yhat3.values, where=Yhat3.values <=1, interpolate=True, color='r')
axes[0].plot(Y3, color = 'b', alpha = 0.75, lw = 2, label = '实际标签')
#axes[0].set_title('validation set', font2,loc='left')
#axes[0].set_xlabel('Time/h',font2)
axes[0].set_yticks([0,1])
axes[0].set_yticklabels(['无攻击','攻击'],font2)
axes[0].legend(loc='upper left',prop=font2)
#axes[0].legend(fontsize = 8, loc = 2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)

axes[1].plot(Yhat4, color = 'r', label = '预测标签')
axes[1].fill_between(Yhat4.index, Yhat4.values, where=Yhat4.values <=1, interpolate=True, color='r')
axes[1].plot(Y4, color = 'b', alpha = 0.75, lw = 2, label = '实际标签')
#axes[1].set_title('test set', font2,loc='left')
#axes[1].set_xlabel('Time/h',font2)
axes[1].set_yticks([0,1])
axes[1].set_yticklabels(['无攻击','攻击'],font2)
axes[1].legend(loc='upper left',prop=font2)
#axes[1].legend(fontsize = 8, loc = 2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)
plt.savefig("f_SAE6.2.png", dpi=1000, bbox_inches = 'tight')
plt.show()
plt.clf()

# %%
cm_plot(Y3,Yhat3)
cm_plot(Y4,Yhat4)
